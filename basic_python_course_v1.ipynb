# %% [markdown]
# ### **Welcome to the Python Basics Course! 🦁**
#
#
# Hi everyone, and welcome! 👋
#
# The goal of this session(s) isn't to turn you into software engineers overnight. Instead, we want to provide you with a practical toolkit of commands that you can actually use when tackling data analysis in your day-to-day work.
#
# The Jump Start Philosophy 🚀 > Think of this notebook as your launching pad. We’re providing the initial momentum and the right tools; the rest of the journey is yours to explore by using Python on a daily basis.
#
# New to Python? 📚
# If you are starting from absolute zero, or if you want to sharpen your foundational skills, we highly recommend checking out these interactive resources:
#
#
# *   DataCamp: Intro to Python for Data Science – Great for hands-on, interactive exercises specifically for data tasks
# *   LearnPython.org – Quick, free, and effective interactive tutorials that you can do right in your browser.

# %% [markdown]
# As a start we take the opportunity to emphasize on the importance of understanding **documentation** when using different libraries.
# Example of useful documentation for Pandas 🐼  Library: https://pandas.pydata.org/docs/index.html

# %% [markdown]
# We will be using an open-source dataset from the seaborn library that contains information on clients in a restaurant 🥘 and the tips they offer.
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Load the data

tips_df = sns.load_dataset("tips")
#add a column with date
tips_df['date']=pd.date_range(start='2025-01-01', periods=len(tips_df), freq='D')

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size       date
# 0       16.99  1.01  Female     No  Sun  Dinner     2 2025-01-01
# 1       10.34  1.66    Male     No  Sun  Dinner     3 2025-01-02
# 2       21.01  3.50    Male     No  Sun  Dinner     3 2025-01-03
# 3       23.68  3.31    Male     No  Sun  Dinner     2 2025-01-04
# 4       24.59  3.61  Female     No  Sun  Dinner     4 2025-01-05

# %%
#check data types
tips_df.dtypes
# Out:
# total_bill           float64
# tip                  float64
# sex                 category
# smoker              category
# day                 category
# time                category
# size                   int64
# date          datetime64[ns]
# dtype: object

# %% [markdown]
# # 🔎 Basic Filtering
#
# In this section we are going to introduce some basic command to filter a dataframe over multiple condition

# %% [markdown]
# ### Filtering with an 'AND' condition

# %% [markdown]
# Let's filter for rows where `sex` is female **AND** `size` is 2

# %%
filtered_by_and= tips_df[(tips_df['sex'] == 'Female') & (tips_df['size'] == 2)]
display(filtered_by_and.head(10))
# Out:
#     total_bill   tip     sex smoker  day    time  size       date
# 0        16.99  1.01  Female     No  Sun  Dinner     2 2025-01-01
# 14       14.83  3.02  Female     No  Sun  Dinner     2 2025-01-15
# 21       20.29  2.75  Female     No  Sat  Dinner     2 2025-01-22
# 22       15.77  2.23  Female     No  Sat  Dinner     2 2025-01-23
# 29       19.65  3.00  Female     No  Sat  Dinner     2 2025-01-30
# 32       15.06  3.00  Female     No  Sat  Dinner     2 2025-02-02
# 51       10.29  2.60  Female     No  Sun  Dinner     2 2025-02-21
# 57       26.41  1.50  Female     No  Sat  Dinner     2 2025-02-27
# 66       16.45  2.47  Female     No  Sat  Dinner     2 2025-03-08
# 72       26.86  3.14  Female    Yes  Sat  Dinner     2 2025-03-14

# %% [markdown]
# ### Filtering with an 'OR' Condition
#
# Let's filter for rows where the `smoker` is 'Yes' **OR** the `day` is 'Sun'.

# %%
filtered_by_or = tips_df[(tips_df['smoker'] == 'Yes') | (tips_df['day'] == 'Sun')]
display(filtered_by_or.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size       date
# 0       16.99  1.01  Female     No  Sun  Dinner     2 2025-01-01
# 1       10.34  1.66    Male     No  Sun  Dinner     3 2025-01-02
# 2       21.01  3.50    Male     No  Sun  Dinner     3 2025-01-03
# 3       23.68  3.31    Male     No  Sun  Dinner     2 2025-01-04
# 4       24.59  3.61  Female     No  Sun  Dinner     4 2025-01-05

# %% [markdown]
# ### Filtering using `isin()` for multiple values
#
# Sometimes you want to filter for rows where a column's value is in a list of possible values. Let's find all tips that occurred on 'Thur' or 'Fri'.

# %%
filtered_by_isin = tips_df[tips_df['day'].isin(['Thur', 'Fri'])]
display(filtered_by_isin.head())
# Out:
#     total_bill   tip   sex smoker   day   time  size       date
# 77       27.20  4.00  Male     No  Thur  Lunch     4 2025-03-19
# 78       22.76  3.00  Male     No  Thur  Lunch     2 2025-03-20
# 79       17.29  2.71  Male     No  Thur  Lunch     2 2025-03-21
# 80       19.44  3.00  Male    Yes  Thur  Lunch     2 2025-03-22
# 81       16.66  3.40  Male     No  Thur  Lunch     2 2025-03-23

# %% [markdown]
# ### Filtering for Numerical Ranges
#
# You can also filter numerical columns for values within a specific range. Let's find all entries where the `total_bill` is between 20 and 30 (inclusive).

# %%
filtered_by_range = tips_df[(tips_df['total_bill'] >= 20) & (tips_df['total_bill'] <= 30)]
display(filtered_by_range.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size       date
# 2       21.01  3.50    Male     No  Sun  Dinner     3 2025-01-03
# 3       23.68  3.31    Male     No  Sun  Dinner     2 2025-01-04
# 4       24.59  3.61  Female     No  Sun  Dinner     4 2025-01-05
# 5       25.29  4.71    Male     No  Sun  Dinner     4 2025-01-06
# 7       26.88  3.12    Male     No  Sun  Dinner     4 2025-01-08

# %% [markdown]
# # **↩ Changing Column Names**

# %%
#checking all column names
tips_df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'date'], dtype='object')

# %%
#change column name size to be more intuitive
tips_df.rename(columns={'size':'party_size'},inplace=True)

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time party_size       date  \
# 0         16.99  1.01  Female     No   Sun  Dinner          2 2025-01-01
# 1         10.34  1.66    Male     No   Sun  Dinner          3 2025-01-02
# 2         21.01  3.50    Male     No   Sun  Dinner          3 2025-01-03
# 3         23.68  3.31    Male     No   Sun  Dinner          2 2025-01-04
# 4         24.59  3.61  Female     No   Sun  Dinner          4 2025-01-05
# ..          ...   ...     ...    ...   ...     ...        ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner          3 2025-08-28
# 240       27.18  2.00  Female    Yes   Sat  Dinner          2 2025-08-29
# 241       22.67  2.00    Male    Yes   Sat  Dinner          2 2025-08-30
# 242       17.82  1.75    Male     No   Sat  Dinner          2 2025-08-31
# 243       18.78  3.00  Female     No  Thur  Dinner          2 2025-09-01
#
#     year_month  year
# 0      2025-01  2025
# 1      2025-01  2025
# 2      2025-01  2025
# ...

# %% [markdown]
# # **↩ Changing data types**

# %%
#check distinct values in size
tips_df['size'].unique()
# Out:
# ['2', '3', '4', '1', '6', '5']
# Categories (6, object): ['1', '2', '3', '4', '5', '6']

# %%
#changing size to str
tips_df['size']=tips_df['size'].astype('category')
tips_df.dtypes
# Out:
# total_bill           float64
# tip                  float64
# sex                 category
# smoker              category
# day                 category
# time                category
# size                category
# date          datetime64[ns]
# year_month         period[M]
# year                   int32
# dtype: object

# %% [markdown]
# # **⏲** **Changing daily data to monthly/yearly**

# %%
# what are the monthly sales ?
#create a new column with year-month
tips_df['year_month']=tips_df['date'].dt.to_period('M')
tips_df.sort_values(by='date',inplace=True)
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size       date year_month
# 0         16.99  1.01  Female     No   Sun  Dinner     2 2025-01-01    2025-01
# 1         10.34  1.66    Male     No   Sun  Dinner     3 2025-01-02    2025-01
# 2         21.01  3.50    Male     No   Sun  Dinner     3 2025-01-03    2025-01
# 3         23.68  3.31    Male     No   Sun  Dinner     2 2025-01-04    2025-01
# 4         24.59  3.61  Female     No   Sun  Dinner     4 2025-01-05    2025-01
# ..          ...   ...     ...    ...   ...     ...   ...        ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3 2025-08-28    2025-08
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2 2025-08-29    2025-08
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2 2025-08-30    2025-08
# 242       17.82  1.75    Male     No   Sat  Dinner     2 2025-08-31    2025-08
# 243       18.78  3.00  Female     No  Thur  Dinner     2 2025-09-01    2025-09
#
# [244 rows x 9 columns]

# %%
#monthly sales
monthly_sales=tips_df.groupby('year_month')['total_bill'].sum()
monthly_sales
# Out:
# year_month
# 2025-01    575.39
# 2025-02    574.46
# 2025-03    602.59
# 2025-04    620.59
# 2025-05    504.69
# 2025-06    654.20
# 2025-07    685.37
# 2025-08    591.70
# 2025-09     18.78
# Freq: M, Name: total_bill, dtype: float64

# %%
#year to-date sales
monthly_sales.sum()
# Out:
# np.float64(4827.7699999999995)

# %%
tips_df['year']=tips_df['date'].dt.year
yearly_sales=tips_df.groupby('year')['total_bill'].sum()
yearly_sales
# Out:
# year
# 2025    4827.77
# Name: total_bill, dtype: float64

# %% [markdown]
# # **⚠ Null Values**

# %%
#setting tip to null when tip is >9
tips_df.loc[tips_df['tip']>9,'tip']=None

# %%
#finding null counts in each column
tips_df.isnull().sum()
# Out:
# total_bill    0
# tip           1
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# date          0
# year_month    0
# year          0
# dtype: int64

# %%
#replacing null value with 10
tips_df['tip']=tips_df['tip'].fillna(10)

# %%
#check to see null value replaced
tips_df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# date          0
# year_month    0
# year          0
# dtype: int64

# %% [markdown]
# # **⚠ Null Values** - part 2
#
# Drop rows with missing values

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with 10 rows and specified columns
data = {
    'id': range(1, 11),
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Heidi', 'Ivan', 'Judy'],
    'surname': ['Smith', 'Johnson', 'Williams', 'Brown', 'Jones', 'Garcia', 'Miller', 'Davis', 'Rodriguez', 'Martinez'],
    'occupation': [
        'Engineer', 'Doctor', 'Artist', None, 'Teacher',
        'Programmer', None, 'Dentist', 'Chef', 'Writer'
    ]
}

df = pd.DataFrame(data)

print("Original DataFrame with missing values:")
display(df)

# Drop rows with any missing values
df_dropped_nulls = df.dropna(axis=0)

print("\nDataFrame after dropping rows with missing values (dropna(axis=0)):")
display(df_dropped_nulls)
# Out:
# Original DataFrame with missing values:
#    id     name    surname  occupation
# 0   1    Alice      Smith    Engineer
# 1   2      Bob    Johnson      Doctor
# 2   3  Charlie   Williams      Artist
# 3   4    David      Brown        None
# 4   5      Eve      Jones     Teacher
# 5   6    Frank     Garcia  Programmer
# 6   7    Grace     Miller        None
# 7   8    Heidi      Davis     Dentist
# 8   9     Ivan  Rodriguez        Chef
# 9  10     Judy   Martinez      Writer
# DataFrame after dropping rows with missing values (dropna(axis=0)):
#    id     name    surname  occupation
# 0   1    Alice      Smith    Engineer
# 1   2      Bob    Johnson      Doctor
# 2   3  Charlie   Williams      Artist
# 4   5      Eve      Jones     Teacher
# 5   6    Frank     Garcia  Programmer
# 7   8    Heidi      Davis     Dentist
# 8   9     Ivan  Rodriguez        Chef
# 9  10     Judy   Martinez      Writer

# %% [markdown]
# # ➕ ➖ **Basic Aritmethic Operations**
#
# What is the % of tip offered from the total bill ?

# %%
tips_df['%tip_from_total_bill']=(tips_df['tip']/tips_df['total_bill'])*100
tips_df['%tip_from_total_bill']=tips_df['%tip_from_total_bill'].round(1)
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size       date  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2 2025-01-01
# 1       10.34  1.66    Male     No  Sun  Dinner     3 2025-01-02
# 2       21.01  3.50    Male     No  Sun  Dinner     3 2025-01-03
# 3       23.68  3.31    Male     No  Sun  Dinner     2 2025-01-04
# 4       24.59  3.61  Female     No  Sun  Dinner     4 2025-01-05
#
#    %tip_from_total_bill
# 0                   5.9
# 1                  16.1
# 2                  16.7
# 3                  14.0
# 4                  14.7

# %% [markdown]
# # **🪣Creating Buckets**

# %%
#observing tips range
tips_df['tip'].max(),tips_df['tip'].min()
# Out:
# (10.0, 1.0)

# %%
tip_bins=[0,5,10]
tip_labels=['low','high']
tips_df['tip_bucket']=pd.cut(tips_df['tip'],bins=tip_bins,labels=tip_labels)

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size       date  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2 2025-01-01
# 1       10.34  1.66    Male     No  Sun  Dinner     3 2025-01-02
# 2       21.01  3.50    Male     No  Sun  Dinner     3 2025-01-03
# 3       23.68  3.31    Male     No  Sun  Dinner     2 2025-01-04
# 4       24.59  3.61  Female     No  Sun  Dinner     4 2025-01-05
#
#    %tip_from_total_bill customer_tier day_type_x day_type_y day_type  \
# 0                   5.9        Silver    Weekend    Weekend  Weekend
# 1                  16.1          Gold    Weekend    Weekend  Weekend
# 2                  16.7          Gold    Weekend    Weekend  Weekend
# 3                  14.0          Gold    Weekend    Weekend  Weekend
# 4                  14.7          Gold    Weekend    Weekend  Weekend
#
#   tip_Bucket tip_bucket
# 0     (0, 5]        low
# 1     (0, 5]        low
# 2     (0, 5]        low
# 3     (0, 5]        low
# 4     (0, 5]        low

# %% [markdown]
# # **🏷 Labelling Data**

# %% [markdown]
# ###Labelling based on a list

# %% [markdown]
# Let's say you would like to flag sales occuring on Public Holidays

# %%
#let's say we have the days of holidays in a list

public_holidays=['2025-01-01','2025-02-10','2025-03-19','2025-03-31']

# %%
#creating a column that labels sales on public holidays
tips_df['public_holiday']=tips_df['date'].isin(public_holidays)
# Out:
# /tmp/ipykernel_11611/571826390.py:2: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   tips_df['public_holiday']=tips_df['date'].isin(public_holidays)

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time party_size       date  \
# 0       16.99  1.01  Female     No  Sun  Dinner          2 2025-01-01
# 1       10.34  1.66    Male     No  Sun  Dinner          3 2025-01-02
# 2       21.01  3.50    Male     No  Sun  Dinner          3 2025-01-03
# 3       23.68  3.31    Male     No  Sun  Dinner          2 2025-01-04
# 4       24.59  3.61  Female     No  Sun  Dinner          4 2025-01-05
#
#   year_month  year  public_holiday  %tip_from_total_bill
# 0    2025-01  2025            True                   5.9
# 1    2025-01  2025           False                  16.1
# 2    2025-01  2025           False                  16.7
# 3    2025-01  2025           False                  14.0
# 4    2025-01  2025           False                  14.7

# %% [markdown]
# 😜 Note: There exists libraries in python with country- based public holidays (https://pypi.org/project/holidays/)

# %% [markdown]
# ###Labelling based on Conditions

# %% [markdown]
# Management would like to assign a loyalty scheme based on % of tip from total bill. There will be two schemes Silver for customers with <10% tip and Gold for customers with >=10% tip.

# %%
tips_df.shape
# Out:
# (244, 9)

# %%
# Define the logical conditions for selection
# You can combine multiple criteria using bitwise operators: & (AND), | (OR)
conditions = [
    (tips_df['%tip_from_total_bill'] <10) ,
    (tips_df['%tip_from_total_bill'] >=10)
]

# Define the corresponding values to assign for each condition
choices = [ 'Silver', 'Gold']

# Create the new column using np.select
# The 'default' argument specifies the value to use if no conditions are met
tips_df['customer_tier'] = np.select(conditions, choices,'Unclassified')

tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size       date  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2 2025-01-01
# 1       10.34  1.66    Male     No  Sun  Dinner     3 2025-01-02
# 2       21.01  3.50    Male     No  Sun  Dinner     3 2025-01-03
# 3       23.68  3.31    Male     No  Sun  Dinner     2 2025-01-04
# 4       24.59  3.61  Female     No  Sun  Dinner     4 2025-01-05
#
#    %tip_from_total_bill customer_tier
# 0                   5.9        Silver
# 1                  16.1          Gold
# 2                  16.7          Gold
# 3                  14.0          Gold
# 4                  14.7          Gold

# %% [markdown]
# # ⚖ Group By

# %% [markdown]
# Are we more making more sales during lunch 🌅 or dinner 🌃 time ?

# %%
#find the sum of  sales generated by time of service
tips_df.groupby('time')['total_bill'].sum()
# Out:
# /tmp/ipykernel_11611/2702684033.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_df.groupby('time')['total_bill'].sum()
# time
# Lunch     1167.47
# Dinner    3660.30
# Name: total_bill, dtype: float64

# %%
# Applying group by with agg
#find the sum of sales and mean tip generated by time of service
tips_df.groupby('time').agg({'total_bill':'sum','tip':'mean' }).rename(columns={'total_bill':'total_bill_sum','tip':'tip_mean'})
#
# Out:
# /tmp/ipykernel_11611/789761943.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_df.groupby('time').agg({'total_bill':'sum','tip':'mean' }).rename(columns={'total_bill':'total_bill_sum','tip':'tip_mean'})
#         total_bill_sum  tip_mean
# time
# Lunch          1167.47  2.728088
# Dinner         3660.30  3.102670

# %% [markdown]
# # 🔝 Most Popular Category

# %% [markdown]
# 🚬 Management are currently considering extending the restaurant area and are unsure whether to make it a smoking zone:🚬
#
# They are also unsure of what table sizes they should purchased 🤔

# %%
#Are our customers mostly smokers or non smokers?
tips_df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
#What are the most common party sizes?
tips_df['party_size'].value_counts()
# Out:
# party_size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %% [markdown]
# # **➿ For Loops**

# %% [markdown]
# What is the mean sale and tip for each day of the week?

# %%
#for each day of the week we find the mean sales and mean tip
for day, group in tips_df.groupby('day'):
  avg_tip=group['tip'].mean()
  avg_sales=group['total_bill'].mean()
  print(f"{day}:avg_tip,avg_sales:{avg_tip},{avg_sales}")
# Out:
# Thur:avg_tip,avg_sales:2.771451612903225,17.682741935483868
# Fri:avg_tip,avg_sales:2.7347368421052627,17.15157894736842
# Sat:avg_tip,avg_sales:2.993103448275862,20.441379310344825
# Sun:avg_tip,avg_sales:3.2551315789473687,21.41
# /tmp/ipykernel_11611/517025852.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for day, group in tips_df.groupby('day'):

# %%
#this can also be achieved with a group by
tips_df.groupby('day').agg({'tip':'mean','total_bill':'mean'})
# Out:
# /tmp/ipykernel_11611/341138084.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_df.groupby('day').agg({'tip':'mean','total_bill':'mean'})
#            tip  total_bill
# day
# Thur  2.771452   17.682742
# Fri   2.734737   17.151579
# Sat   2.993103   20.441379
# Sun   3.255132   21.410000

# %% [markdown]
# # **🪡 Joins**

# %%
# we have data from Thursday - Sunday only
tips_df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
# let us consider we have another data set indicating whether a day falls in weekend or weekday
day_info = pd.DataFrame({
    'day': ['Thur', 'Fri', 'Sat', 'Sun'],
    'day_type': ['Weekday', 'Weekday', 'Weekend', 'Weekend']
})
day_info
# Out:
#     day day_type
# 0  Thur  Weekday
# 1   Fri  Weekday
# 2   Sat  Weekend
# 3   Sun  Weekend

# %%
#joining day_info to tips_df
tips_df=tips_df.merge(day_info,on='day',how='left')
tips_df.head(-50)
# Out:
#      total_bill   tip     sex smoker   day    time  size       date  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2 2025-01-01
# 1         10.34  1.66    Male     No   Sun  Dinner     3 2025-01-02
# 2         21.01  3.50    Male     No   Sun  Dinner     3 2025-01-03
# 3         23.68  3.31    Male     No   Sun  Dinner     2 2025-01-04
# 4         24.59  3.61  Female     No   Sun  Dinner     4 2025-01-05
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 189       23.10  4.00    Male    Yes   Sun  Dinner     3 2025-07-09
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2 2025-07-10
# 191       19.81  4.19  Female    Yes  Thur   Lunch     2 2025-07-11
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2 2025-07-12
# 193       15.48  2.02    Male    Yes  Thur   Lunch     2 2025-07-13
#
#      %tip_from_total_bill customer_tier day_type_x day_type_y day_type
# 0                     5.9        Silver    Weekend    Weekend  Weekend
# ...

# %% [markdown]
# # **🧪 Statistical Tests**
# The statistical test choice depends on the **hypothesis** you would like to test and the **data**. Here we will demonstate a test specific to the hypothesis we would like to test and the data we have.

# %% [markdown]
# Question: Does tip amount differ by whether customer is a smoker or not ?

# %%
# Here we have unpaired data

# %%
#testing for normality
from scipy.stats import kstest, norm
#seperate the data based on whether customer is a smoker or not
smoker_data=tips_df[tips_df['smoker']=='Yes']['tip']
non_smoker_data=tips_df[tips_df['smoker']=='No']['tip']
#standarizing the data for KS test
smoker_std=(smoker_data-smoker_data.mean())/smoker_data.std()
non_smoker_std=(non_smoker_data-non_smoker_data.mean())/non_smoker_data.std()
#KS test
smoker_ks_stat, smoker_p = kstest(smoker_std, 'norm')
nonsmoker_ks_stat, nonsmoker_p = kstest(non_smoker_std, 'norm')

print(f"Smoker KS p-value: {smoker_p:.4f}")
print(f"Non-Smoker KS p-value: {nonsmoker_p:.4f}")
# Out:
# Smoker KS p-value: 0.1770
# Non-Smoker KS p-value: 0.0535

# %%
tips_df['tip'].min()
# Out:
# 1.0

# %%
# we can also see normality by plotting distributions
import matplotlib.pyplot as plt
sns.histplot(smoker_std, kde=True, label='Smoker',color='#c11717')
sns.histplot(non_smoker_std, kde=True, label='Non-Smoker',color='#d9b608')
plt.legend()
plt.xlabel("Standardized Tip")
plt.ylabel("Count")
plt.title("Tip Distribution: Smokers vs Non-Smokers")

plt.show()

# %%
#Data seems to be approx. normal as p>0.05
# We will use an independent samples t-test
from scipy.stats import ttest_ind
stat, p_val = ttest_ind(smoker_data, non_smoker_data)
print(f"statistic={stat}, p_val={p_val}")
# Out:
# statistic=0.09222805186888201, p_val=0.9265931522244976

# %% [markdown]
# pvalue>0.05.-> **No statistically significant difference** between tips from smokers and non-smokers

# %% [markdown]
# # 📊 Extract a random sample

# %%
import numpy as np
import pandas as pd

# Generate 100 random 4-digit integers (1000-9999)
player_ids = np.random.randint(1000, 10000, size=101)

# Create a DataFrame with the player_id column
player_df = pd.DataFrame({'player_id': player_ids})

print("Generated DataFrame with 100 player IDs:")
display(player_df.head())
# Out:
# Generated DataFrame with 100 player IDs:
#    player_id
# 0       2357
# 1       8382
# 2       4272
# 3       8454
# 4       2987

# %%
control = player_df.sample(frac=0.1)
test = player_df.loc[~player_df.index.isin(control.index)]

print("Number of players in Control")
display(control['player_id'].nunique())
print("Number of players in Test")
display(test['player_id'].nunique())
# Out:
# Number of players in Control
# 10
# Number of players in Test
# 90

# %% [markdown]
# # ⛽ Run a SQL script and loading the results in a Pandas Dataframe
# In this section we will:
#
#
# *   import the main libraries required to interrogate a BigQuery environment
# *   Import our Google credentials
# *   Launch a SQL code in our Jupyter notebook
# *   Load the results of the SQL query in a Pandas dataframe

# %%
# 0. Loading the bigquery translator
# !pip install sqlalchemy-bigquery --quiet

import pandas as pd
from sqlalchemy import create_engine
from google.colab import auth

# 1. Google autenthication
auth.authenticate_user()

# 2. creating the bigquery engine
engine = create_engine('bigquery://leo-production-bi')

# %%
import time

# 3. SQL query
query = """
SELECT * FROM `leo-production-bi.DW_Fact_Management_Analysis.fact_core_daily_no_personal_history`
WHERE date = CURRENT_DATE - 1
LIMIT 1000
"""

print("Fetching data from BigQuery...")

# --- START TIMER ---
start_time = time.time()

# 4. Use native Pandas to read the SQL
df = pd.read_sql(query, engine)

# --- END TIMER ---
end_time = time.time()

# Calculate and print the duration
execution_time = end_time - start_time
print(f"✅ Done! Query executed in: {execution_time:.2f} seconds\n")

display(df.head())
# Out:
# Fetching data from BigQuery...
# ✅ Done! Query executed in: 2.22 seconds
#   player_key currency        date  day period_description  week  YearWeek_num  \
# 0  220969544     None  2026-03-25   25                M2D    13      202613.0
# 1  223958496     None  2026-03-25   25                M2D    13      202613.0
# 2  221242085     None  2026-03-25   25                M2D    13      202613.0
# 3  222434016     None  2026-03-25   25                M2D    13      202613.0
# 4  223947790     None  2026-03-25   25                M2D    13      202613.0
#
#    Last12Weeks game_key vertical  ... license_uid reactivated_deposit30  \
# 0  Last12Weeks     None     None  ...         MGA                     0
# 1  Last12Weeks     None     None  ...         MGA                     0
# 2  Last12Weeks     None     None  ...         MGA                     0
# 3  Last12Weeks     None     None  ...         MGA                     0
# ...
